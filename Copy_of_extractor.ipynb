# %%
# #Collector

# import scrapy


# class PlayerSpider(scrapy.Spider):
#     name = 'player'
#     codes=[
#         2,25,1,6,5,7,3,8,4,9,
#         40,19,29,20,30,27,21,104,41,111,108,42,115,
#         12,112,116,117,118,114,43,17,39,44,121,122,
#         4082,123,125,126,13,129,4251,10,131,33,133,
#         35,135,18,137,1094,142,148,147,22,31,36,4083,
#         26,38,159,161,169,16,164,45,165,171,6411,28,32,
#         15,173,175,37,183,178,179,185,187,191,192,154,
#         194,196,23,197,195,200,201,202,4253,204,205,211,
#         207,209,206,34,11,216,215,24,48
#     ]
#     classes=2
#     start_urls=[]
#     for code in codes:
#         start_urls.append('http://www.espncricinfo.com/ci/content/player/caps.html?country={codeem};class={classem}'.format(codeem=code, classem=classes)) 

#     def parse(self, response):
#         for player in response.css('li.sep'):
#             yield {
#                 'text': player.css('a.ColumnistSmry::text').get(),
#                 'link': player.css('a.ColumnistSmry::attr("href")').get(),
#             }

# %%
#extractor

import json
import requests
from bs4 import BeautifulSoup

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f116ac57-651c-4de6-90ff-1e45ccbff9e8" name="files[]" multiple disabled />
#      <output id="result-f116ac57-651c-4de6-90ff-1e45ccbff9e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
readLink = []
with open("player.json", "r") as read_file:
    readLink = json.load(read_file)

start_urls=[]
player_names=[]

for link in readLink:
    dia = link['link']
    dia = dia[12:]
    start_urls.append('http://stats.espncricinfo.com/ci/engine/{val}?class=2;template=results;type=batting'.format(val = dia)) 
    player_names.append(link['text'])

# %%
def check(runs):
    try:
        int(runs)
    except:
        return 'error'

def detcall(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    results = soup.find_all('table', attrs={'class': 'engineTable'})
    result2= results[3].find_all('tbody')
    result3=result2[4].find_all('tr', attrs={'class': 'data1'})
    

    #check year
    yearres=str(result3[1].find('b').text)
    if('year' not in yearres):
        result3=result2[5].find_all('tr', attrs={'class': 'data1'})
    
    result3=result3[1:]

    #check run
    runwrapcheck=False
    siblingres=[]
    for sibling in result3[0].td.next_siblings:
        siblingres.append(repr(sibling))
#    print(siblingres)
    runyeartagind=9
#    print(runyeartagind)
    runyeartag=siblingres[runyeartagind]
    start=runyeartag.find('<td>')
    end=runyeartag.find('</td>')
    runsres=runyeartag[start+4: end]
    if (check(runsres) == 'error'):
        if('nowrap' in runsres):
            runwrapcheck=True
        else:
            runyeartagind=7
#        print('changed',runyeartagind)

    dictres={}
    for res in result3:
        #find year
        yearres=str(res.find('b').text)
        # print(yearres)
        # if('year' not in yearres):
        #     return {}
        
        #find runs in that year
        siblingres=[]
        for sibling in res.td.next_siblings:
            siblingres.append(repr(sibling))
        runyeartag=siblingres[runyeartagind]
        start=runyeartag.find('<td>')
        end=runyeartag.find('</td>')
        runsres=runyeartag[start+4: end]
        #add result found to the result dictionary
        if('nowrap' in runsres):
            runsres='0'
        dictres[yearres]=runsres

    return dictres

# %%
final_res={}

for i in range(len(player_names)):
    print(player_names[i], start_urls[i], i)
    if(player_names[i]=='RD Jackman'):
        print('\n\nHERE THE RESULT CHECK\n\n')
    detrun=detcall(start_urls[i])
    print(player_names[i], detrun)
    final_res[player_names[i]]=detrun
# Out:
# (u'G Boycott', 'http://stats.espncricinfo.com/ci/engine/player/9187.html?class=2;template=results;type=batting', 0)
# (u'G Boycott', {'year 1979': '493', 'year 1978': '9', 'year 1977': '0', 'year 1973': '35', 'year 1972': '74', 'year 1971': '8', 'year 1981': '113', 'year 1980': '350'})
# (u'MC Cowdrey', 'http://stats.espncricinfo.com/ci/engine/player/10846.html?class=2;template=results;type=batting', 1)
# (u'MC Cowdrey', {'year 1971': '1'})
# (u"BL D'Oliveira", 'http://stats.espncricinfo.com/ci/engine/player/11914.html?class=2;template=results;type=batting', 2)
# (u"BL D'Oliveira", {'year 1972': '13', 'year 1971': '17'})
# (u'JH Edrich', 'http://stats.espncricinfo.com/ci/engine/player/12490.html?class=2;template=results;type=batting', 3)
# (u'JH Edrich', {'year 1975': '8', 'year 1974': '133', 'year 1971': '82'})
# (u'KWR Fletcher', 'http://stats.espncricinfo.com/ci/engine/player/12854.html?class=2;template=results;type=batting', 4)
# (u'KWR Fletcher', {'year 1982': '119', 'year 1975': '267', 'year 1974': '96', 'year 1973': '106', 'year 1972': '114', 'year 1971': '24', 'year 1981': '31'})
# (u'JH Hampshire', 'http://stats.espncricinfo.com/ci/engine/player/14024.html?class=2;template=results;type=batting', 5)
# (u'JH Hampshire', {'year 1972': '38', 'year 1971': '10'})
# (u'R Illingworth', 'http://stats.espncricinfo.com/ci/engine/player/15385.html?class=2;template=results;type=batting', 6)
# (u'R Illingworth', {'year 1973': '4', 'year 1971': '1'})
# (u'APE Knott', 'http://stats.espncricinfo.com/ci/engine/player/15917.html?class=2;template=results;type=batting', 7)
# (u'APE Knott', {'year 1977': '25', 'year 1976': '48', 'year 1975': '20', 'year 1974': '15', 'year 1973': '12', 'year 1972': '56', 'year 1971': '24'})
# (u'P Lever', 'http://stats.espncricinfo.com/ci/engine/player/16262.html?class=2;template=results;type=batting', 8)
# (u'P Lever', {'year 1975': '5', 'year 1974': '8', 'year 1973': '0', 'year 1971': '4'})
# (u'K Shuttleworth', 'http://stats.espncricinfo.com/ci/engine/player/20182.html?class=2;template=results;type=batting', 9)
# (u'K Shuttleworth', {'year 1971': '7'})
# (u'JA Snow', 'http://stats.espncricinfo.com/ci/engine/player/20282.html?class=2;template=results;type=batting', 10)
# (u'JA Snow', {'year 1975': '2', 'year 1973': '0', 'year 1972': '5', 'year 1971': '2'})
# (u'DL Amiss', 'http://stats.espncricinfo.com/ci/engine/player/8535.html?class=2;template=results;type=batting', 11)
# (u'DL Amiss', {'year 1977': '151', 'year 1976': '93', 'year 1975': '293', 'year 1974': '20', 'year 1973': '134', 'year 1972': '168'})
# (u'GG Arnold', 'http://stats.espncricinfo.com/ci/engine/player/8566.html?class=2;template=results;type=batting', 12)
# (u'GG Arnold', {'year 1975': '18', 'year 1974': '2', 'year 1973': '17', 'year 1972': '11'})
# (u'DB Close', 'http://stats.espncricinfo.com/ci/engine/player/10754.html?class=2;template=results;type=batting', 13)
# (u'DB Close', {'year 1972': '49'})
# (u'AW Greig', 'http://stats.espncricinfo.com/ci/engine/player/13463.html?class=2;template=results;type=batting', 14)
# (u'AW Greig', {'year 1977': '26', 'year 1976': '5', 'year 1975': '32', 'year 1974': '72', 'year 1973': '79', 'year 1972': '55'})
# (u'RA Woolmer', 'http://stats.espncricinfo.com/ci/engine/player/22520.html?class=2;template=results;type=batting', 15)
# (u'RA Woolmer', {'year 1976': '12', 'year 1974': '0', 'year 1972': '9'})
# (u'SJ Cook', 'http://stats.espncricinfo.com/ci/engine/player/44465.html?class=2;template=results;type=batting', 16)
# (u'SJ Cook', {'year 1991': '52', 'year 1993': '15'})
# (u'Asif Iqbal', 'http://stats.espncricinfo.com/ci/engine/player/39010.html?class=2;template=results;type=batting', 17)
# (u'Asif Iqbal', {'year 1979': '129', 'year 1978': '62', 'year 1977': '59', 'year 1975': '53', 'year 1974': '24', 'year 1973': '3'})
# (u'B Wood', 'http://stats.espncricinfo.com/ci/engine/player/22498.html?class=2;template=results;type=batting', 18)
# (u'B Wood', {'year 1976': '38', 'year 1975': '130', 'year 1982': '93', 'year 1972': '19', 'year 1978': '34'})
# (u'FC Hayes', 'http://stats.espncricinfo.com/ci/engine/player/14106.html?class=2;template=results;type=batting', 19)
# (u'FC Hayes', {'year 1975': '90', 'year 1973': '38'})
# (u'GRJ Roope', 'http://stats.espncricinfo.com/ci/engine/player/19469.html?class=2;template=results;type=batting', 20)
# (u'GRJ Roope', {'year 1977': '36', 'year 1973': '44', 'year 1978': '93'})
# (u'DL Underwood', 'http://stats.espncricinfo.com/ci/engine/player/22149.html?class=2;template=results;type=batting', 21)
# (u'DL Underwood', {'year 1979': '0', 'year 1977': '5', 'year 1976': '22', 'year 1975': '3', 'year 1974': '17', 'year 1973': '2', 'year 1981': '0', 'year 1982': '4'})
# (u'MH Denness', 'http://stats.espncricinfo.com/ci/engine/player/11870.html?class=2;template=results;type=batting', 22)
# (u'MH Denness', {'year 1975': '125', 'year 1974': '73', 'year 1973': '66'})
# (u'M Hendrick', 'http://stats.espncricinfo.com/ci/engine/player/14159.html?class=2;template=results;type=batting', 23)
# (u'M Hendrick', {'year 1979': '1', 'year 1978': '2', 'year 1977': '0', 'year 1976': '1', 'year 1975': '1', 'year 1973': '1', 'year 1980': '0', 'year 1981': '0'})
# (u'CM Old', 'http://stats.espncricinfo.com/ci/engine/player/18256.html?class=2;template=results;type=batting', 24)
# (u'CM Old', {'year 1979': '18', 'year 1978': '35', 'year 1977': '81', 'year 1975': '128', 'year 1974': '44', 'year 1973': '25', 'year 1980': '6', 'year 1981': '1'})
# (u'MJ Smith', 'http://stats.espncricinfo.com/ci/engine/player/20257.html?class=2;template=results;type=batting', 25)
# (u'MJ Smith', {'year 1974': '20', 'year 1973': '50'})
# (u'RW Taylor', 'http://stats.espncricinfo.com/ci/engine/player/21494.html?class=2;template=results;type=batting', 26)
# (u'RW Taylor', {'year 1979': '32', 'year 1978': '12', 'year 1977': '0', 'year 1982': '9', 'year 1975': '23', 'year 1974': '26', 'year 1973': '11', 'year 1983': '7', 'year 1984': '10'})
# (u'RGD Willis', 'http://stats.espncricinfo.com/ci/engine/player/22462.html?class=2;template=results;type=batting', 27)
# (u'RGD Willis', {'year 1979': '27', 'year 1978': '0', 'year 1977': '7', 'year 1982': '2', 'year 1984': '14', 'year 1974': '0', 'year 1973': '9', 'year 1983': '21', 'year 1980': '0', 'year 1981': '3'})
# (u'JA Jameson', 'http://stats.espncricinfo.com/ci/engine/player/15468.html?class=2;template=results;type=batting', 28)
# (u'JA Jameson', {'year 1975': '32', 'year 1973': '28'})
# (u'D Lloyd', 'http://stats.espncricinfo.com/ci/engine/player/16318.html?class=2;template=results;type=batting', 29)
# (u'D Lloyd', {'year 1975': '49', 'year 1974': '193', 'year 1973': '8', 'year 1980': '1', 'year 1978': '34'})
# (u'RD Jackman', 'http://stats.espncricinfo.com/ci/engine/player/15461.html?class=2;template=results;type=batting', 30)
#
#
# HERE THE RESULT CHECK
#
#
# (u'RD Jackman', {'year 1976': '14', 'year 1974': '0', 'year 1983': '18', 'year 1980': '6', 'year 1981': '16'})
# (u'BW Luckhurst', 'http://stats.espncricinfo.com/ci/engine/player/16370.html?class=2;template=results;type=batting', 31)
# (u'BW Luckhurst', {'year 1975': '15'})
# (u'AA Donald', 'http://stats.espncricinfo.com/ci/engine/player/44716.html?class=2;template=results;type=batting', 32)
# (u'AA Donald', {'year 1999': '10', 'year 1998': '19', 'year 1995': '5', 'year 1994': '9', 'year 1997': '21', 'year 1996': '0', 'year 1991': '0', 'year 1993': '12', 'year 1992': '8', 'year 2002': '6', 'year 2003': '0', 'year 2000': '1', 'year 2001': '4'})
# (u'AC Hudson', 'http://stats.espncricinfo.com/ci/engine/player/45458.html?class=2;template=results;type=batting', 33)
# (u'AC Hudson', {'year 1995': '70', 'year 1994': '480', 'year 1997': '97', 'year 1996': '950', 'year 1991': '0', 'year 1993': '302', 'year 1992': '660'})
# (u'PN Kirsten', 'http://stats.espncricinfo.com/ci/engine/player/45815.html?class=2;template=results;type=batting', 34)
# (u'PN Kirsten', {'year 1994': '387', 'year 1991': '95', 'year 1993': '139', 'year 1992': '672'})
# (u'AP Kuiper', 'http://stats.espncricinfo.com/ci/engine/player/45840.html?class=2;template=results;type=batting', 35)
# (u'AP Kuiper', {'year 1995': '64', 'year 1994': '138', 'year 1996': '61', 'year 1991': '127', 'year 1992': '149'})
# (u'BM McMillan', 'http://stats.espncricinfo.com/ci/engine/player/46214.html?class=2;template=results;type=batting', 36)
# (u'BM McMillan', {'year 1998': '17', 'year 1995': '127', 'year 1994': '33', 'year 1997': '36', 'year 1996': '335', 'year 1991': '2', 'year 1993': '153', 'year 1992': '138'})
# (u'CEB Rice', 'http://stats.espncricinfo.com/ci/engine/player/46976.html?class=2;template=results;type=batting', 37)
# (u'CEB Rice', {'year 1991': '26'})
# (u'DJ Richardson', 'http://stats.espncricinfo.com/ci/engine/player/46978.html?class=2;template=results;type=batting', 38)
# (u'DJ Richardson', {'year 1998': '12', 'year 1995': '50', 'year 1994': '349', 'year 1997': '102', 'year 1996': '118', 'year 1991': '9', 'year 1993': '122', 'year 1992': '106'})
# (u'TG Shaw', 'http://stats.espncricinfo.com/ci/engine/player/47184.html?class=2;template=results;type=batting', 39)
# (u'TG Shaw', {'year 1994': '26', 'year 1991': '0'})
# (u'RP Snell', 'http://stats.espncricinfo.com/ci/engine/player/47215.html?class=2;template=results;type=batting', 40)
# (u'RP Snell', {'year 1994': '74', 'year 1996': '79', 'year 1991': '18', 'year 1993': '118', 'year 1992': '33'})
# (u'KC Wessels', 'http://stats.espncricinfo.com/ci/engine/player/47884.html?class=2;template=results;type=batting', 41)
# (u'KC Wessels', {'year 1994': '317', 'year 1984': '802', 'year 1985': '509', 'year 1991': '211', 'year 1983': '429', 'year 1993': '390', 'year 1992': '709'})
# (u'CE Eksteen', 'http://stats.espncricinfo.com/ci/engine/player/44954.html?class=2;template=results;type=batting', 42)
# (u'CE Eksteen', {'year 1994': '0', 'year 1991': '6'})
# (u'CR Matthews', 'http://stats.espncricinfo.com/ci/engine/player/46189.html?class=2;template=results;type=batting', 43)
# (u'CR Matthews', {'year 1995': '22', 'year 1994': '61', 'year 1997': '0', 'year 1996': '27', 'year 1991': '10', 'year 1993': '19', 'year 1992': '2'})
# (u'M Yachad', 'http://stats.espncricinfo.com/ci/engine/player/48102.html?class=2;template=results;type=batting', 44)
# (u'M Yachad', {'year 1991': '31'})
# (u'WJ Cronje', 'http://stats.espncricinfo.com/ci/engine/player/44485.html?class=2;template=results;type=batting', 45)
# (u'WJ Cronje', {'year 1999': '587', 'year 1998': '691', 'year 1995': '157', 'year 1994': '1133', 'year 1997': '771', 'year 1996': '933', 'year 1993': '395', 'year 1992': '330', 'year 2000': '568'})
# (u'Asif Masood', 'http://stats.espncricinfo.com/ci/engine/player/39012.html?class=2;template=results;type=batting', 46)
# (u'Asif Masood', {'year 1976': '0', 'year 1975': '6', 'year 1974': '0', 'year 1973': '4'})
# (u'Intikhab Alam', 'http://stats.espncricinfo.com/ci/engine/player/40567.html?class=2;template=results;type=batting', 47)
# (u'Intikhab Alam', {'year 1976': '7', 'year 1974': '0', 'year 1973': '10'})
# (u'Majid Khan', 'http://stats.espncricinfo.com/ci/engine/player/41919.html?class=2;template=results;type=batting', 48)
# (u'Majid Khan', {'year 1979': '150', 'year 1978': '87', 'year 1977': '23', 'year 1976': '20', 'year 1975': '209', 'year 1974': '109', 'year 1973': '8', 'year 1980': '66', 'year 1981': '76', 'year 1982': '38'})
# (u'Mushtaq Mohammad', 'http://stats.espncricinfo.com/ci/engine/player/41318.html?class=2;template=results;type=batting', 49)
# (u'Mushtaq Mohammad', {'year 1976': '46', 'year 1975': '89', 'year 1974': '25', 'year 1973': '27', 'year 1978': '22'})
# (u'Nasim-ul-Ghani', 'http://stats.espncricinfo.com/ci/engine/player/42057.html?class=2;template=results;type=batting', 50)
# (u'Nasim-ul-Ghani', {'year 1973': '1'})
# (u'Sadiq Mohammad', 'http://stats.espncricinfo.com/ci/engine/player/42601.html?class=2;template=results;type=batting', 51)
# (u'Sadiq Mohammad', {'year 1979': '104', 'year 1978': '13', 'year 1977': '21', 'year 1976': '17', 'year 1975': '85', 'year 1974': '53', 'year 1973': '37', 'year 1980': '53'})
# (u'Saleem Altaf', 'http://stats.espncricinfo.com/ci/engine/player/42616.html?class=2;template=results;type=batting', 52)
# (u'Saleem Altaf', {'year 1977': '4', 'year 1973': '21', 'year 1978': '0'})
# (u'Sarfraz Nawaz', 'http://stats.espncricinfo.com/ci/engine/player/42630.html?class=2;template=results;type=batting', 53)
# (u'Sarfraz Nawaz', {'year 1979': '12', 'year 1978': '34', 'year 1977': '2', 'year 1976': '0', 'year 1975': '0', 'year 1974': '0', 'year 1973': '17', 'year 1983': '53', 'year 1980': '8', 'year 1981': '39', 'year 1982': '31', 'year 1984': '25'})
# (u'Wasim Bari', 'http://stats.espncricinfo.com/ci/engine/player/43549.html?class=2;template=results;type=batting', 54)
# (u'Wasim Bari', {'year 1979': '26', 'year 1978': '31', 'year 1977': '2', 'year 1976': '2', 'year 1975': '3', 'year 1974': '0', 'year 1973': '21', 'year 1983': '81', 'year 1980': '0', 'year 1981': '4', 'year 1982': '18', 'year 1984': '33'})
# (u'Wasim Raja', 'http://stats.espncricinfo.com/ci/engine/player/43553.html?class=2;template=results;type=batting', 55)
# (u'Wasim Raja', {'year 1985': '78', 'year 1979': '39', 'year 1978': '44', 'year 1977': '79', 'year 1976': '8', 'year 1975': '91', 'year 1974': '0', 'year 1973': '4', 'year 1983': '41', 'year 1980': '46', 'year 1981': '47', 'year 1982': '196', 'year 1984': '109'})
# (u'Imran Khan', 'http://stats.espncricinfo.com/ci/engine/player/40560.html?class=2;template=results;type=batting', 56)
# (u'Imran Khan', {'year 1991': '225', 'year 1985': '255', 'year 1988': '181', 'year 1979': '42', 'year 1978': '12', 'year 1977': '39', 'year 1976': '4', 'year 1975': '9', 'year 1974': '0', 'year 1982': '284', 'year 1983': '283', 'year 1980': '2', 'year 1981': '76', 'year 1986': '186', 'year 1987': '437', 'year 1992': '229', 'year 1989': '793', 'year 1984': '156', 'year 1990': '496'})
# (u'Zaheer Abbas', 'http://stats.espncricinfo.com/ci/engine/player/43695.html?class=2;template=results;type=batting', 57)
# (u'Zaheer Abbas', {'year 1985': '198', 'year 1979': '148', 'year 1978': '91', 'year 1977': '10', 'year 1976': '23', 'year 1975': '136', 'year 1974': '88', 'year 1982': '677', 'year 1983': '494', 'year 1980': '137', 'year 1981': '229', 'year 1984': '341'})
# (u'Naseer Malik', 'http://stats.espncricinfo.com/ci/engine/player/42055.html?class=2;template=results;type=batting', 58)
# (u'Naseer Malik', {'year 1975': '0'})
# (u'Javed Miandad', 'http://stats.espncricinfo.com/ci/engine/player/40879.html?class=2;template=results;type=batting', 59)
# (u'Javed Miandad', {'year 1991': '141', 'year 1996': '54', 'year 1988': '607', 'year 1979': '46', 'year 1978': '57', 'year 1977': '100', 'year 1976': '47', 'year 1975': '52', 'year 1985': '721', 'year 1982': '501', 'year 1983': '293', 'year 1980': '47', 'year 1981': '194', 'year 1986': '632', 'year 1993': '590', 'year 1987': '1084', 'year 1992': '942', 'year 1989': '487', 'year 1984': '475', 'year 1990': '311'})
# (u'FJ Titmus', 'http://stats.espncricinfo.com/ci/engine/player/21548.html?class=2;template=results;type=batting', 60)
# (u'FJ Titmus', {'year 1975': '11'})
# (u'GD Barlow', 'http://stats.espncricinfo.com/ci/engine/player/8990.html?class=2;template=results;type=batting', 61)
# (u'GD Barlow', {'year 1977': '69', 'year 1976': '80'})
# (u'IT Botham', 'http://stats.espncricinfo.com/ci/engine/player/9163.html?class=2;template=results;type=batting', 62)
# (u'IT Botham', {'year 1991': '8', 'year 1979': '145', 'year 1978': '80', 'year 1977': '32', 'year 1976': '21', 'year 1984': '91', 'year 1985': '101', 'year 1982': '188', 'year 1983': '275', 'year 1980': '156', 'year 1981': '159', 'year 1986': '51', 'year 1987': '394', 'year 1992': '375', 'year 1989': '37'})
# (u'GA Gooch', 'http://stats.espncricinfo.com/ci/engine/player/13399.html?class=2;template=results;type=batting', 63)
# (u'GA Gooch', {'year 1991': '244', 'year 1994': '82', 'year 1988': '110', 'year 1979': '316', 'year 1978': '94', 'year 1986': '330', 'year 1976': '40', 'year 1985': '289', 'year 1982': '141', 'year 1990': '401', 'year 1980': '297', 'year 1981': '158', 'year 1995': '2', 'year 1993': '135', 'year 1987': '840', 'year 1992': '430', 'year 1989': '381'})
# (u'JK Lever', 'http://stats.espncricinfo.com/ci/engine/player/16260.html?class=2;template=results;type=batting', 64)
# (u'JK Lever', {'year 1979': '1', 'year 1978': '5', 'year 1977': '30', 'year 1976': '1', 'year 1982': '2', 'year 1980': '17', 'year 1981': '0'})
# (u'DS Steele', 'http://stats.espncricinfo.com/ci/engine/player/20345.html?class=2;template=results;type=batting', 65)
# (u'DS Steele', {'year 1976': '8'})
# (u'DW Randall', 'http://stats.espncricinfo.com/ci/engine/player/19327.html?class=2;template=results;type=batting', 66)
# (u'DW Randall', {'year 1979': '200', 'year 1978': '73', 'year 1977': '111', 'year 1976': '127', 'year 1984': '149', 'year 1985': '19', 'year 1982': '30', 'year 1983': '342', 'year 1980': '16'})
# (u'JM Brearley', 'http://stats.espncricinfo.com/ci/engine/player/9208.html?class=2;template=results;type=batting', 67)
# (u'JM Brearley', {'year 1977': '147', 'year 1980': '34', 'year 1979': '270', 'year 1978': '59'})
# (u'P Willey', 'http://stats.espncricinfo.com/ci/engine/player/22442.html?class=2;template=results;type=batting', 68)
# (u'P Willey', {'year 1979': '244', 'year 1977': '7', 'year 1985': '12', 'year 1980': '124', 'year 1981': '100', 'year 1986': '51'})
# (u'G Miller', 'http://stats.espncricinfo.com/ci/engine/player/17025.html?class=2;template=results;type=batting', 69)
# (u'G Miller', {'year 1979': '4', 'year 1978': '2', 'year 1977': '20', 'year 1984': '20', 'year 1982': '26', 'year 1983': '64'})
# (u'PR Downton', 'http://stats.espncricinfo.com/ci/engine/player/11931.html?class=2;template=results;type=batting', 70)
# (u'PR Downton', {'year 1988': '30', 'year 1977': '0', 'year 1987': '19', 'year 1984': '71', 'year 1985': '94', 'year 1986': '28'})
# (u'PH Edmonds', 'http://stats.espncricinfo.com/ci/engine/player/12486.html?class=2;template=results;type=batting', 71)
# (u'PH Edmonds', {'year 1979': '22', 'year 1978': '4', 'year 1977': '5', 'year 1987': '16', 'year 1984': '0', 'year 1985': '69', 'year 1986': '0'})
# (u'MW Gatting', 'http://stats.espncricinfo.com/ci/engine/player/13340.html?class=2;template=results;type=batting', 72)
# (u'MW Gatting', {'year 1988': '306', 'year 1978': '3', 'year 1977': '22', 'year 1987': '681', 'year 1984': '231', 'year 1985': '124', 'year 1982': '142', 'year 1983': '83', 'year 1980': '19', 'year 1981': '278', 'year 1986': '102', 'year 1993': '46', 'year 1989': '58'})
# (u'BC Rose', 'http://stats.espncricinfo.com/ci/engine/player/19478.html?class=2;template=results;type=batting', 73)
# (u'BC Rose', {'year 1977': '99'})
# (u'GS Chappell', 'http://stats.espncricinfo.com/ci/engine/player/4558.html?class=2;template=results;type=batting', 74)
# (u'GS Chappell', {'year 1979': '273', 'year 1977': '174', 'year 1975': '232', 'year 1974': '117', 'year 1982': '338', 'year 1972': '101', 'year 1971': '22', 'year 1981': '454', 'year 1983': '274', 'year 1980': '346'})
# (u'Gazi Ashraf', 'http://stats.espncricinfo.com/ci/engine/player/55896.html?class=2;template=results;type=batting', 75)
# (u'Gazi Ashraf', {'year 1986': '10', 'year 1990': '26', 'year 1988': '23'})
# (u'DS de Silva', 'http://stats.espncricinfo.com/ci/engine/player/48454.html?class=2;template=results;type=batting', 76)
# (u'DS de Silva', {'year 1979': '7', 'year 1984': '61', 'year 1985': '53', 'year 1982': '31', 'year 1983': '172', 'year 1975': '47'})
# (u'MG Burgess', 'http://stats.espncricinfo.com/ci/engine/player/36314.html?class=2;template=results;type=batting', 77)
# (u'MG Burgess', {'year 1979': '45', 'year 1978': '1', 'year 1976': '38', 'year 1974': '6', 'year 1973': '48', 'year 1980': '108', 'year 1981': '90'})
# (u'MW Pringle', 'http://stats.espncricinfo.com/ci/engine/player/46790.html?class=2;template=results;type=batting', 78)
# (u'MW Pringle', {'year 1994': '13', 'year 1993': '20', 'year 1992': '15'})
# (u'JN Rhodes', 'http://stats.espncricinfo.com/ci/engine/player/46973.html?class=2;template=results;type=batting', 79)
# (u'JN Rhodes', {'year 1999': '386', 'year 1998': '596', 'year 1995': '144', 'year 1994': '819', 'year 1997': '578', 'year 1996': '560', 'year 1993': '363', 'year 1992': '333', 'year 2002': '1066', 'year 2003': '2', 'year 2000': '551', 'year 2001': '537'})
# (u'T Bosch', 'http://stats.espncricinfo.com/ci/engine/player/44097.html?class=2;template=results;type=batting', 80)
# (u'T Bosch', {'year 1992': '0'})
# (u'O Henry', 'http://stats.espncricinfo.com/ci/engine/player/45437.html?class=2;template=results;type=batting', 81)
# (u'O Henry', {'year 1992': '20'})
# (u'MW Rushmere', 'http://stats.espncricinfo.com/ci/engine/player/47011.html?class=2;template=results;type=batting', 82)
# (u'MW Rushmere', {'year 1992': '78'})
# (u'CJPG van Zyl', 'http://stats.espncricinfo.com/ci/engine/player/47715.html?class=2;template=results;type=batting', 83)
# (u'CJPG van Zyl', {'year 1992': '3'})
# (u'DJ Callaghan', 'http://stats.espncricinfo.com/ci/engine/player/44416.html?class=2;template=results;type=batting', 84)
# (u'DJ Callaghan', {'year 1995': '51', 'year 1994': '272', 'year 2000': '15', 'year 1993': '41', 'year 1992': '114'})
# (u'PS de Villiers', 'http://stats.espncricinfo.com/ci/engine/player/44696.html?class=2;template=results;type=batting', 85)
# (u'PS de Villiers', {'year 1995': '20', 'year 1994': '68', 'year 1997': '7', 'year 1996': '55', 'year 1993': '20', 'year 1992': '0'})
# (u'BN Schultz', 'http://stats.espncricinfo.com/ci/engine/player/47165.html?class=2;template=results;type=batting', 86)
# (u'BN Schultz', {'year 1992': '0'})
# (u'DJ Cullinan', 'http://stats.espncricinfo.com/ci/engine/player/44489.html?class=2;template=results;type=batting', 87)
# (u'DJ Cullinan', {'year 1999': '517', 'year 1998': '408', 'year 1995': '147', 'year 1994': '475', 'year 1997': '810', 'year 1996': '1034', 'year 1993': '238', 'year 2000': '231'})
# (u'ELR Stewart', 'http://stats.espncricinfo.com/ci/engine/player/47239.html?class=2;template=results;type=batting', 88)
# (u'ELR Stewart', {'year 2002': '4', 'year 1994': '32', 'year 1993': '25'})
# (u'PL Symcox', 'http://stats.espncricinfo.com/ci/engine/player/47267.html?class=2;template=results;type=batting', 89)
# (u'PL Symcox', {'year 1999': '24', 'year 1998': '196', 'year 1995': '48', 'year 1994': '20', 'year 1997': '118', 'year 1996': '250', 'year 1993': '38'})
# (u'S Abid Ali', 'http://stats.espncricinfo.com/ci/engine/player/26169.html?class=2;template=results;type=batting', 90)
# (u'S Abid Ali', {'year 1975': '70', 'year 1974': '23'})
# (u'Pervez Mir', 'http://stats.espncricinfo.com/ci/engine/player/42323.html?class=2;template=results;type=batting', 91)
# (u'Pervez Mir', {'year 1977': '18', 'year 1975': '8'})
# (u'Mohsin Khan', 'http://stats.espncricinfo.com/ci/engine/player/41303.html?class=2;template=results;type=batting', 92)
# (u'Mohsin Khan', {'year 1978': '69', 'year 1977': '15', 'year 1984': '283', 'year 1985': '411', 'year 1982': '471', 'year 1983': '256', 'year 1981': '46', 'year 1986': '326'})
# (u'Aamer Hameed', 'http://stats.espncricinfo.com/ci/engine/player/38963.html?class=2;template=results;type=batting', 93)
# (u'Aamer Hameed', {'year 1977': '0', 'year 1978': '0'})
# (u'Hasan Jamil', 'http://stats.espncricinfo.com/ci/engine/player/40376.html?class=2;template=results;type=batting', 94)
# (u'Hasan Jamil', {'year 1977': '48', 'year 1978': '63'})
# (u'Liaqat Ali', 'http://stats.espncricinfo.com/ci/engine/player/41246.html?class=2;template=results;type=batting', 95)
# (u'Liaqat Ali', {'year 1977': '0', 'year 1978': ' class="padAst">7'})
# (u'Mudassar Nazar', 'http://stats.espncricinfo.com/ci/engine/player/41308.html?class=2;template=results;type=batting', 96)
# (u'Mudassar Nazar', {'year 1988': '209', 'year 1979': '3', 'year 1978': '104', 'year 1977': '53', 'year 1987': '226', 'year 1984': '281', 'year 1985': '575', 'year 1982': '372', 'year 1983': '194', 'year 1980': '7', 'year 1981': '200', 'year 1986': '356', 'year 1989': '73'})
# (u'Shafiq Ahmed', 'http://stats.espncricinfo.com/ci/engine/player/42636.html?class=2;template=results;type=batting', 97)
# (u'Shafiq Ahmed', {'year 1977': '38', 'year 1978': '3'})
# (u'Haroon Rasheed', 'http://stats.espncricinfo.com/ci/engine/player/40375.html?class=2;template=results;type=batting', 98)
# (u'Haroon Rasheed', {'year 1977': '5', 'year 1982': '71', 'year 1979': '69', 'year 1978': '21'})
# (u'Iqbal Qasim', 'http://stats.espncricinfo.com/ci/engine/player/40572.html?class=2;template=results;type=batting', 99)
# (u'Iqbal Qasim', {'year 1988': '0', 'year 1978': '9', 'year 1977': '0', 'year 1985': '9', 'year 1982': '15', 'year 1980': '6', 'year 1981': '0'})
# (u'Sikander Bakht', 'http://stats.espncricinfo.com/ci/engine/player/42661.html?class=2;template=results;type=batting', 100)
# (u'Sikander Bakht', {'year 1979': '3', 'year 1978': '16', 'year 1977': '0', 'year 1989': '6', 'year 1982': '3', 'year 1980': '0', 'year 1981': '3'})
# (u'Arshad Pervez', 'http://stats.espncricinfo.com/ci/engine/player/39006.html?class=2;template=results;type=batting', 101)
# (u'Arshad Pervez', {'year 1978': '11'})
# (u'Naeem Ahmed', 'http://stats.espncricinfo.com/ci/engine/player/42071.html?class=2;template=results;type=batting', 102)
# (u'Naeem Ahmed', {'year 1978': '0'})
# (u'Azmat Rana', 'http://stats.espncricinfo.com/ci/engine/player/39026.html?class=2;template=results;type=batting', 103)
# (u'Azmat Rana', {'year 1978': '42'})
# (u'GA Cope', 'http://stats.espncricinfo.com/ci/engine/player/10809.html?class=2;template=results;type=batting', 104)
# (u'GA Cope', {'year 1977': '0', 'year 1978': '1*'})
# (u'DI Gower', 'http://stats.espncricinfo.com/ci/engine/player/13418.html?class=2;template=results;type=batting', 105)
# (u'DI Gower', {'year 1991': '54', 'year 1979': '302', 'year 1978': '201', 'year 1986': '137', 'year 1987': '341', 'year 1984': '201', 'year 1985': '231', 'year 1982': '189', 'year 1983': '1086', 'year 1980': '76', 'year 1981': '141', 'year 1989': '125', 'year 1990': '86'})
# (u'CT Radley', 'http://stats.espncricinfo.com/ci/engine/player/19316.html?class=2;template=results;type=batting', 106)
# (u'CT Radley', {'year 1978': '250'})
# (u'RW Tolchard', 'http://stats.espncricinfo.com/ci/engine/player/21550.html?class=2;template=results;type=batting', 107)
# (u'RW Tolchard', {'year 1979': '0'})
# (u'DL Bairstow', 'http://stats.espncricinfo.com/ci/engine/player/8954.html?class=2;template=results;type=batting', 108)
# (u'DL Bairstow', {'year 1984': '30', 'year 1980': '99', 'year 1979': '56', 'year 1981': '21'})
# (u'W Larkins', 'http://stats.espncricinfo.com/ci/engine/player/16203.html?class=2;template=results;type=batting', 109)
# (u'W Larkins', {'year 1990': '228', 'year 1991': '40', 'year 1980': '77', 'year 1979': '7', 'year 1989': '239'})
# (u'GR Dilley', 'http://stats.espncricinfo.com/ci/engine/player/11893.html?class=2;template=results;type=batting', 110)
# (u'GR Dilley', {'year 1988': '0', 'year 1979': '1', 'year 1986': '8', 'year 1987': '10', 'year 1984': '1', 'year 1982': '1', 'year 1983': '90', 'year 1980': '0', 'year 1981': '3'})
# (u'JE Emburey', 'http://stats.espncricinfo.com/ci/engine/player/12514.html?class=2;template=results;type=batting', 111)
# (u'JE Emburey', {'year 1988': '62', 'year 1989': '10', 'year 1986': '42', 'year 1987': '326', 'year 1982': '0', 'year 1980': '26', 'year 1981': '5', 'year 1993': '30'})
# (u'GB Stevenson', 'http://stats.espncricinfo.com/ci/engine/player/20363.html?class=2;template=results;type=batting', 112)
# (u'GB Stevenson', {'year 1980': '29', 'year 1981': '14'})
# (u'CJ Tavare', 'http://stats.espncricinfo.com/ci/engine/player/21466.html?class=2;template=results;type=batting', 113)
# (u'CJ Tavare', {'year 1984': '4', 'year 1982': '173', 'year 1983': '456', 'year 1980': '87'})
# (u'VJ Marks', 'http://stats.espncricinfo.com/ci/engine/player/16899.html?class=2;template=results;type=batting', 114)
# (u'VJ Marks', {'year 1984': '108', 'year 1985': '50', 'year 1988': '0', 'year 1983': '118', 'year 1980': '9'})
# (u'IM Chappell', 'http://stats.espncricinfo.com/ci/engine/player/4560.html?class=2;template=results;type=batting', 115)
# (u'IM Chappell', {'year 1979': '123', 'year 1975': '226', 'year 1974': '169', 'year 1972': '87', 'year 1980': '8', 'year 1971': '60'})
# (u'AN Connolly', 'http://stats.espncricinfo.com/ci/engine/player/4613.html?class=2;template=results;type=batting', 116)
# (u'AN Connolly', {'year 1971': '0'})
# (u'WM Lawry', 'http://stats.espncricinfo.com/ci/engine/player/6270.html?class=2;template=results;type=batting', 117)
# (u'WM Lawry', {'year 1971': '27'})
# (u'GD McKenzie', 'http://stats.espncricinfo.com/ci/engine/player/6576.html?class=2;template=results;type=batting', 118)
# (u'GD McKenzie', {'year 1971': '0'})
# (u'AA Mallett', 'http://stats.espncricinfo.com/ci/engine/player/6472.html?class=2;template=results;type=batting', 119)
# (u'AA Mallett', {'year 1975': '0', 'year 1974': '0', 'year 1972': '14', 'year 1971': '0'})
# (u'RW Marsh', 'http://stats.espncricinfo.com/ci/engine/player/6502.html?class=2;template=results;type=batting', 120)
# (u'RW Marsh', {'year 1979': '100', 'year 1977': '43', 'year 1975': '92', 'year 1974': '1', 'year 1982': '101', 'year 1972': '17', 'year 1971': '10', 'year 1981': '215', 'year 1983': '257', 'year 1980': '107', 'year 1984': '282'})
# (u'IR Redpath', 'http://stats.espncricinfo.com/ci/engine/player/7314.html?class=2;template=results;type=batting', 121)
# (u'IR Redpath', {'year 1975': '26', 'year 1974': '8', 'year 1971': '12'})
# (u'KR Stackpole', 'http://stats.espncricinfo.com/ci/engine/player/7666.html?class=2;template=results;type=batting', 122)
# (u'KR Stackpole', {'year 1974': '61', 'year 1972': '150', 'year 1971': '13'})
# (u'AL Thomson', 'http://stats.espncricinfo.com/ci/engine/player/7944.html?class=2;template=results;type=batting', 123)
# (u'AL Thomson', {'year 1971': '0'})
# (u'KD Walters', 'http://stats.espncricinfo.com/ci/engine/player/8151.html?class=2;template=results;type=batting', 124)
# (u'KD Walters', {'year 1979': '46', 'year 1977': '12', 'year 1975': '141', 'year 1974': '19', 'year 1972': '17', 'year 1971': '41', 'year 1981': '177', 'year 1980': '60'})
# (u'R Edwards', 'http://stats.espncricinfo.com/ci/engine/player/5124.html?class=2;template=results;type=batting', 125)
# (u'R Edwards', {'year 1975': '186', 'year 1972': '69'})
# (u'Gholam Nousher', 'http://stats.espncricinfo.com/ci/engine/player/55898.html?class=2;template=results;type=batting', 126)
# (u'Gholam Nousher', {'year 1986': '4', 'year 1990': '4', 'year 1988': '0'})
# (u'Golam Faruq', 'http://stats.espncricinfo.com/ci/engine/player/55897.html?class=2;template=results;type=batting', 127)
# (u'Golam Faruq', {'year 1986': '17', 'year 1990': '0', 'year 1988': '27'})
# (u'Hafizur Rahman', 'http://stats.espncricinfo.com/ci/engine/player/55907.html?class=2;template=results;type=batting', 128)
# (u'Hafizur Rahman', {'year 1986': '8'})
# (u'Jahangir Shah', 'http://stats.espncricinfo.com/ci/engine/player/55933.html?class=2;template=results;type=batting', 129)
# (u'Jahangir Shah', {'year 1986': '1', 'year 1990': '0', 'year 1988': '15'})
# (u'Minhajul Abedin', 'http://stats.espncricinfo.com/ci/engine/player/55971.html?class=2;template=results;type=batting', 130)
# (u'Minhajul Abedin', {'year 1999': '140', 'year 1998': '73', 'year 1988': '43', 'year 1986': '46', 'year 1997': '44', 'year 1990': '60', 'year 1995': '47'})
# (u'Nurul Abedin', 'http://stats.espncricinfo.com/ci/engine/player/56040.html?class=2;template=results;type=batting', 131)
# (u'Nurul Abedin', {'year 1986': '13', 'year 1990': '2'})
# (u'Rafiqul Alam', 'http://stats.espncricinfo.com/ci/engine/player/56066.html?class=2;template=results;type=batting', 132)
# (u'Rafiqul Alam', {'year 1986': '24'})
# (u'Raqibul Hasan', 'http://stats.espncricinfo.com/ci/engine/player/56070.html?class=2;template=results;type=batting', 133)
# (u'Raqibul Hasan', {'year 1986': '17'})
# (u'Samiur Rahman', 'http://stats.espncricinfo.com/ci/engine/player/56097.html?class=2;template=results;type=batting', 134)
# (u'Samiur Rahman', {'year 1986': '4'})
# (u'Shaheedur Rahman', 'http://stats.espncricinfo.com/ci/engine/player/56102.html?class=2;template=results;type=batting', 135)
# (u'Shaheedur Rahman', {'year 1986': '62'})
# (u'Aminul Islam', 'http://stats.espncricinfo.com/ci/engine/player/56224.html?class=2;template=results;type=batting', 136)
# (u'Aminul Islam', {'year 1999': '180', 'year 1998': '189', 'year 1988': '37', 'year 1995': '72', 'year 1997': '126', 'year 1990': '75', 'year 2002': '31', 'year 2000': '82', 'year 2001': '2'})
# (u'Athar Ali Khan', 'http://stats.espncricinfo.com/ci/engine/player/56227.html?class=2;template=results;type=batting', 137)
# (u'Athar Ali Khan', {'year 1995': '21', 'year 1997': '259', 'year 1990': '122', 'year 1988': '68', 'year 1998': '62'})
# (u'Azhar Hossain', 'http://stats.espncricinfo.com/ci/engine/player/56229.html?class=2;template=results;type=batting', 138)
# (u'Azhar Hossain', {'year 1990': '82', 'year 1988': '14'})
# (u'Harunur Rashid', 'http://stats.espncricinfo.com/ci/engine/player/55912.html?class=2;template=results;type=batting', 139)
# (u'Harunur Rashid', {'year 1988': '0'})
# (u'ER Fernando', 'http://stats.espncricinfo.com/ci/engine/player/48804.html?class=2;template=results;type=batting', 140)
# (u'ER Fernando', {'year 1975': '47'})
# (u'PD Heyn', 'http://stats.espncricinfo.com/ci/engine/player/49131.html?class=2;template=results;type=batting', 141)
# (u'PD Heyn', {'year 1975': '3'})
# (u'LWS Kaluperuma', 'http://stats.espncricinfo.com/ci/engine/player/49487.html?class=2;template=results;type=batting', 142)
# (u'LWS Kaluperuma', {'year 1975': '19', 'year 1982': '14'})
# (u'LRD Mendis', 'http://stats.espncricinfo.com/ci/engine/player/49629.html?class=2;template=results;type=batting', 143)
# (u'LRD Mendis', {'year 1988': '135', 'year 1979': '78', 'year 1989': '27', 'year 1986': '158', 'year 1987': '227', 'year 1984': '63', 'year 1985': '436', 'year 1982': '169', 'year 1983': '194', 'year 1975': '40'})
# (u'ARM Opatha', 'http://stats.espncricinfo.com/ci/engine/player/49849.html?class=2;template=results;type=batting', 144)
# (u'ARM Opatha', {'year 1975': '11', 'year 1979': '18'})
# (u'HSM Pieris', 'http://stats.espncricinfo.com/ci/engine/player/49861.html?class=2;template=results;type=batting', 145)
# (u'HSM Pieris', {'year 1975': '19'})
# (u'AN Ranasinghe', 'http://stats.espncricinfo.com/ci/engine/player/50241.html?class=2;template=results;type=batting', 146)
# (u'AN Ranasinghe', {'year 1975': '23', 'year 1982': '130'})
# (u'APB Tennekoon', 'http://stats.espncricinfo.com/ci/engine/player/50742.html?class=2;template=results;type=batting', 147)
# (u'APB Tennekoon', {'year 1975': '78', 'year 1979': '59'})
# (u'MH Tissera', 'http://stats.espncricinfo.com/ci/engine/player/50745.html?class=2;template=results;type=batting', 148)
# (u'MH Tissera', {'year 1975': '78'})
# (u'B Warnapura', 'http://stats.espncricinfo.com/ci/engine/player/50835.html?class=2;template=results;type=batting', 149)
# (u'B Warnapura', {'year 1975': '41', 'year 1982': '101', 'year 1979': '38'})
# (u'SRD Wettimuny', 'http://stats.espncricinfo.com/ci/engine/player/50840.html?class=2;template=results;type=batting', 150)
# (u'SRD Wettimuny', {'year 1975': '53', 'year 1979': '83'})
# (u'GRA de Silva', 'http://stats.espncricinfo.com/ci/engine/player/48458.html?class=2;template=results;type=batting', 151)
# (u'GRA de Silva', {'year 1975': '0', 'year 1982': '7', 'year 1979': '2'})
# (u'DLS de Silva', 'http://stats.espncricinfo.com/ci/engine/player/48453.html?class=2;template=results;type=batting', 152)
# (u'DLS de Silva', {'year 1979': '10'})
# (u'RL Dias', 'http://stats.espncricinfo.com/ci/engine/player/48470.html?class=2;template=results;type=batting', 153)
# (u'RL Dias', {'year 1979': '75', 'year 1986': '33', 'year 1987': '127', 'year 1984': '115', 'year 1985': '587', 'year 1982': '479', 'year 1983': '157'})
# (u'RO Collinge', 'http://stats.espncricinfo.com/ci/engine/player/36606.html?class=2;template=results;type=batting', 154)
# (u'RO Collinge', {'year 1976': '5', 'year 1975': '8', 'year 1974': '0', 'year 1973': '13', 'year 1978': '8'})
# (u'PG Coman', 'http://stats.espncricinfo.com/ci/engine/player/36608.html?class=2;template=results;type=batting', 155)
# (u'PG Coman', {'year 1974': '38', 'year 1973': '24'})
# (u'BE Congdon', 'http://stats.espncricinfo.com/ci/engine/player/36611.html?class=2;template=results;type=batting', 156)
# (u'BE Congdon', {'year 1976': '47', 'year 1975': '101', 'year 1974': '131', 'year 1973': '5', 'year 1978': '54'})
# (u'DR Hadlee', 'http://stats.espncricinfo.com/ci/engine/player/37222.html?class=2;template=results;type=batting', 157)
# (u'DR Hadlee', {'year 1976': '0', 'year 1975': '28', 'year 1974': '12', 'year 1973': '0'})
# (u'Sir RJ Hadlee', 'http://stats.espncricinfo.com/ci/engine/player/37224.html?class=2;template=results;type=batting', 158)
# (u'Sir RJ Hadlee', {'year 1985': '154', 'year 1988': '291', 'year 1979': '57', 'year 1978': '2', 'year 1986': '307', 'year 1976': '0', 'year 1975': '27', 'year 1974': '3', 'year 1973': '49', 'year 1983': '293', 'year 1980': '115', 'year 1981': '144', 'year 1982': '36', 'year 1987': '53', 'year 1989': '0', 'year 1984': '72', 'year 1990': '148'})
# (u'BF Hastings', 'http://stats.espncricinfo.com/ci/engine/player/37243.html?class=2;template=results;type=batting', 159)
# (u'BF Hastings', {'year 1975': '113', 'year 1974': '34', 'year 1973': '4'})
# (u'HJ Howarth', 'http://stats.espncricinfo.com/ci/engine/player/37255.html?class=2;template=results;type=batting', 160)
# (u'HJ Howarth', {'year 1975': '12', 'year 1973': '6'})
# (u'GM Turner', 'http://stats.espncricinfo.com/ci/engine/player/38622.html?class=2;template=results;type=batting', 161)
# (u'GM Turner', {'year 1979': '176', 'year 1976': '182', 'year 1975': '359', 'year 1974': '11', 'year 1973': '36', 'year 1983': '834'})
# (u'GE Vivian', 'http://stats.espncricinfo.com/ci/engine/player/38711.html?class=2;template=results;type=batting', 162)
# (u'GE Vivian', {'year 1973': '14'})
# (u'KJ Wadsworth', 'http://stats.espncricinfo.com/ci/engine/player/38735.html?class=2;template=results;type=batting', 163)
# (u'KJ Wadsworth', {'year 1976': '46', 'year 1975': '68', 'year 1974': '111', 'year 1973': '33'})
# (u'V Pollard', 'http://stats.espncricinfo.com/ci/engine/player/38129.html?class=2;template=results;type=batting', 164)
# (u'V Pollard', {'year 1974': '12', 'year 1973': '55'})
# (u'RE Redmond', 'http://stats.espncricinfo.com/ci/engine/player/38244.html?class=2;template=results;type=batting', 165)
# (u'RE Redmond', {'year 1973': '3'})
# (u'BR Taylor', 'http://stats.espncricinfo.com/ci/engine/player/38609.html?class=2;template=results;type=batting', 166)
# (u'BR Taylor', {'year 1973': '22'})
# (u'G Kirsten', 'http://stats.espncricinfo.com/ci/engine/player/45813.html?class=2;template=results;type=batting', 167)
# (u'G Kirsten', {'year 1999': '465', 'year 1998': '561', 'year 1995': '362', 'year 1994': '610', 'year 1997': '593', 'year 1996': '1442', 'year 1993': '11', 'year 2002': '463', 'year 2003': '186', 'year 2000': '1467', 'year 2001': '638'})
# (u'DB Rundle', 'http://stats.espncricinfo.com/ci/engine/player/47010.html?class=2;template=results;type=batting', 168)
# (u'DB Rundle', {'year 1994': '6'})
# (u'EO Simons', 'http://stats.espncricinfo.com/ci/engine/player/47190.html?class=2;template=results;type=batting', 169)
# (u'EO Simons', {'year 1995': '20', 'year 1994': '197'})
# (u'DN Crookes', 'http://stats.espncricinfo.com/ci/engine/player/44486.html?class=2;template=results;type=batting', 170)
# (u'DN Crookes', {'year 1999': '33', 'year 1998': '53', 'year 1994': '30', 'year 1997': '39', 'year 1996': '121', 'year 2000': '20'})
# (u'MJR Rindel', 'http://stats.espncricinfo.com/ci/engine/player/46987.html?class=2;template=results;type=batting', 171)
# (u'MJR Rindel', {'year 1995': '151', 'year 1994': '64', 'year 1999': '39', 'year 1998': '321'})
# (u'SD Jack', 'http://stats.espncricinfo.com/ci/engine/player/45711.html?class=2;template=results;type=batting', 172)
# (u'SD Jack', {'year 1995': '6', 'year 1994': '1'})
# (u'N Boje', 'http://stats.espncricinfo.com/ci/engine/player/44091.html?class=2;template=results;type=batting', 173)
# (u'N Boje', {'year 1999': '19', 'year 1998': '28', 'year 1995': '0', 'year 1996': '27', 'year 2002': '336', 'year 2003': '54', 'year 2000': '588', 'year 2001': '145', 'year 2004': '142', 'year 2005': '75'})
# (u'GFJ Liebenberg', 'http://stats.espncricinfo.com/ci/engine/player/45984.html?class=2;template=results;type=batting', 174)
# (u'GFJ Liebenberg', {'year 1995': '12', 'year 1998': '82'})
# (u'PJR Steyn', 'http://stats.espncricinfo.com/ci/engine/player/47242.html?class=2;template=results;type=batting', 175)
# (u'PJR Steyn', {'year 1995': '4'})
# (u'PR Adams', 'http://stats.espncricinfo.com/ci/engine/player/43919.html?class=2;template=results;type=batting', 176)
# (u'PR Adams', {'year 1999': '0', 'year 1998': '15', 'year 1997': '0', 'year 1996': '10', 'year 2002': '0', 'year 2003': '33', 'year 2000': '2', 'year 2001': '6'})
# (u'JH Kallis', 'http://stats.espncricinfo.com/ci/engine/player/45789.html?class=2;template=results;type=batting', 177)
# (u'JH Kallis', {'year 2013': '76', 'year 2012': '126', 'year 1999': '944', 'year 1998': '812', 'year 1997': '519', 'year 1996': '275', 'year 2014': '5', 'year 2011': '370', 'year 2008': '557', 'year 2009': '538', 'year 2010': '593', 'year 2002': '1204', 'year 2003': '595', 'year 2000': '1300', 'year 2001': '848', 'year 2006': '373', 'year 2007': '987', 'year 2004': '770', 'year 2005': '687'})
# (u'SM Pollock', 'http://stats.espncricinfo.com/ci/engine/player/46774.html?class=2;template=results;type=batting', 178)
# (u'SM Pollock', {'year 1999': '278', 'year 1998': '289', 'year 1997': '438', 'year 1996': '160', 'year 2008': '43', 'year 2002': '362', 'year 2003': '170', 'year 2000': '185', 'year 2001': '110', 'year 2006': '379', 'year 2007': '541', 'year 2004': '278', 'year 2005': '286'})
# (u'L Klusener', 'http://stats.espncricinfo.com/ci/engine/player/45821.html?class=2;template=results;type=batting', 179)
# (u'L Klusener', {'year 1999': '854', 'year 1998': '297', 'year 1997': '472', 'year 1996': '95', 'year 2002': '510', 'year 2003': '91', 'year 2000': '817', 'year 2001': '245', 'year 2004': '195'})
# (u'SJ Palframan', 'http://stats.espncricinfo.com/ci/engine/player/46724.html?class=2;template=results;type=batting', 180)
# (u'SJ Palframan', {'year 1996': '55'})
# (u'BS Bedi', 'http://stats.espncricinfo.com/ci/engine/player/26875.html?class=2;template=results;type=batting', 181)
# (u'BS Bedi', {'year 1976': '4', 'year 1975': '6', 'year 1974': '0', 'year 1979': '19', 'year 1978': '2'})
# (u'FM Engineer', 'http://stats.espncricinfo.com/ci/engine/player/28624.html?class=2;template=results;type=batting', 182)
# (u'FM Engineer', {'year 1975': '78', 'year 1974': '36'})
# (u'SM Gavaskar', 'http://stats.espncricinfo.com/ci/engine/player/28794.html?class=2;template=results;type=batting', 183)
# (u'SM Gavaskar', {'year 1985': '414', 'year 1979': '89', 'year 1978': '4', 'year 1986': '805', 'year 1987': '735', 'year 1975': '113', 'year 1974': '48', 'year 1982': '194', 'year 1983': '383', 'year 1980': '44', 'year 1981': '113', 'year 1984': '150'})
# (u'S Madan Lal', 'http://stats.espncricinfo.com/ci/engine/player/30873.html?class=2;template=results;type=batting', 184)
# (u'S Madan Lal', {'year 1985': '18', 'year 1986': '63', 'year 1976': '21', 'year 1975': '20', 'year 1974': '5', 'year 1982': '54', 'year 1983': '153', 'year 1981': '6', 'year 1987': '39', 'year 1984': '22'})
# (u'SS Naik', 'http://stats.espncricinfo.com/ci/engine/player/31778.html?class=2;template=results;type=batting', 185)
# (u'SS Naik', {'year 1974': '38'})
# (u'BP Patel', 'http://stats.espncricinfo.com/ci/engine/player/32231.html?class=2;template=results;type=batting', 186)
# (u'BP Patel', {'year 1976': '61', 'year 1975': '25', 'year 1974': '94', 'year 1979': '63'})
# (u'ED Solkar', 'http://stats.espncricinfo.com/ci/engine/player/34085.html?class=2;template=results;type=batting', 187)
# (u'ED Solkar', {'year 1976': '3', 'year 1975': '21', 'year 1974': '3'})
# (u'S Venkataraghavan', 'http://stats.espncricinfo.com/ci/engine/player/35656.html?class=2;template=results;type=batting', 188)
# (u'S Venkataraghavan', {'year 1979': '23', 'year 1978': '0', 'year 1976': '1', 'year 1975': '26', 'year 1974': '1', 'year 1983': '3'})
# (u'GR Viswanath', 'http://stats.espncricinfo.com/ci/engine/player/35712.html?class=2;template=results;type=batting', 189)
# (u'GR Viswanath', {'year 1979': '106', 'year 1978': '17', 'year 1976': '56', 'year 1975': '39', 'year 1974': '36', 'year 1982': '9', 'year 1980': '77', 'year 1981': '99'})
# (u'AL Wadekar', 'http://stats.espncricinfo.com/ci/engine/player/35933.html?class=2;template=results;type=batting', 190)
# (u'AL Wadekar', {'year 1974': '73'})
# (u'GK Bose', 'http://stats.espncricinfo.com/ci/engine/player/26966.html?class=2;template=results;type=batting', 191)
# (u'GK Bose', {'year 1974': '13'})
# (u'AV Mankad', 'http://stats.espncricinfo.com/ci/engine/player/30938.html?class=2;template=results;type=batting', 192)
# (u'AV Mankad', {'year 1974': '44'})
# (u'M Amarnath', 'http://stats.espncricinfo.com/ci/engine/player/26225.html?class=2;template=results;type=batting', 193)
# (u'M Amarnath', {'year 1988': '584', 'year 1979': '16', 'year 1978': '85', 'year 1986': '309', 'year 1976': '29', 'year 1975': '1', 'year 1985': '64', 'year 1982': '71', 'year 1983': '468', 'year 1987': '33', 'year 1989': '258', 'year 1984': '6'})
# (u'AD Gaekwad', 'http://stats.espncricinfo.com/ci/engine/player/28754.html?class=2;template=results;type=batting', 194)
# (u'AD Gaekwad', {'year 1979': '54', 'year 1978': '94', 'year 1976': '16', 'year 1975': '59', 'year 1983': '22', 'year 1987': '12', 'year 1984': '12'})
# (u'Mansoor Akhtar', 'http://stats.espncricinfo.com/ci/engine/player/41263.html?class=2;template=results;type=batting', 195)
# (u'Mansoor Akhtar', {'year 1989': '31', 'year 1987': '132', 'year 1984': '181', 'year 1982': '170', 'year 1983': '9', 'year 1980': '24', 'year 1981': '14', 'year 1990': '32'})
# (u'Mohammad Nazir', 'http://stats.espncricinfo.com/ci/engine/player/41294.html?class=2;template=results;type=batting', 196)
# (u'Mohammad Nazir', {'year 1984': '2', 'year 1983': '0', 'year 1980': '2'})
# (u'Taslim Arif', 'http://stats.espncricinfo.com/ci/engine/player/43275.html?class=2;template=results;type=batting', 197)
# (u'Taslim Arif', {'year 1980': '28'})
# (u'Ashraf Ali', 'http://stats.espncricinfo.com/ci/engine/player/39008.html?class=2;template=results;type=batting', 198)
# (u'Ashraf Ali', {'year 1984': '17', 'year 1985': '19', 'year 1982': '3', 'year 1980': '0', 'year 1981': '30'})
# (u'Ijaz Faqih', 'http://stats.espncricinfo.com/ci/engine/player/40556.html?class=2;template=results;type=batting', 199)
# (u'Ijaz Faqih', {'year 1988': '6', 'year 1987': '0', 'year 1984': '67', 'year 1982': '6', 'year 1983': '61', 'year 1980': '0', 'year 1981': '57'})
# (u'Rashid Khan', 'http://stats.espncricinfo.com/ci/engine/player/42421.html?class=2;template=results;type=batting', 200)
# (u'Rashid Khan', {'year 1984': '72', 'year 1985': '25', 'year 1982': '0', 'year 1983': '9', 'year 1980': '4'})
# (u'Saleem Pervez', 'http://stats.espncricinfo.com/ci/engine/player/42624.html?class=2;template=results;type=batting', 201)
# (u'Saleem Pervez', {'year 1980': '18'})
# (u'Tahir Naqqash', 'http://stats.espncricinfo.com/ci/engine/player/43271.html?class=2;template=results;type=batting', 202)
# (u'Tahir Naqqash', {'year 1984': '13', 'year 1985': '129', 'year 1982': '45', 'year 1983': '1', 'year 1980': '0', 'year 1981': '22'})
# (u'Rizwan-uz-Zaman', 'http://stats.espncricinfo.com/ci/engine/player/42428.html?class=2;template=results;type=batting', 203)
# (u'Rizwan-uz-Zaman', {'year 1986': '4', 'year 1987': '2', 'year 1981': '14'})
# (u'Saleem Malik', 'http://stats.espncricinfo.com/ci/engine/player/42623.html?class=2;template=results;type=batting', 204)
# (u'Saleem Malik', {'year 1991': '185', 'year 1996': '904', 'year 1999': '116', 'year 1998': '171', 'year 1988': '539', 'year 1989': '931', 'year 1986': '107', 'year 1987': '799', 'year 1984': '149', 'year 1985': '251', 'year 1982': '0', 'year 1983': '27', 'year 1993': '221', 'year 1990': '603', 'year 1995': '227', 'year 1994': '748', 'year 1992': '654', 'year 1997': '538'})
# (u'Jalal-ud-Din', 'http://stats.espncricinfo.com/ci/engine/player/40872.html?class=2;template=results;type=batting', 205)
# (u'Jalal-ud-Din', {'year 1982': '0', 'year 1983': '5'})
# (u'Saleem Yousuf', 'http://stats.espncricinfo.com/ci/engine/player/42626.html?class=2;template=results;type=batting', 206)
# ...
# (u'ACI Lock', {'year 1996': '8'})
# (u'CB Wishart', 'http://stats.espncricinfo.com/ci/engine/player/55854.html?class=2;template=results;type=batting', 1252)
# (u'CB Wishart', {'year 1999': '0', 'year 1998': '411', 'year 1997': '171', 'year 1996': '62', 'year 2002': '54', 'year 2003': '433', 'year 2000': '112', 'year 2001': '473', 'year 2005': '3'})
# (u'AR Whittall', 'http://stats.espncricinfo.com/ci/engine/player/55846.html?class=2;template=results;type=batting', 1253)
# (u'AR Whittall', {'year 2000': '1', 'year 1997': '23', 'year 1996': '5', 'year 1999': '36', 'year 1998': '103'})
# (u'GB Brent', 'http://stats.espncricinfo.com/ci/engine/player/55269.html?class=2;template=results;type=batting', 1254)
# (u'GB Brent', {'year 1999': '10', 'year 1998': '24', 'year 1996': '1', 'year 2008': '44', 'year 2002': '16', 'year 2003': '10', 'year 2000': '36', 'year 2001': '87', 'year 2006': '49', 'year 2007': '113', 'year 2004': '18'})
# (u'GJ Rennie', 'http://stats.espncricinfo.com/ci/engine/player/55713.html?class=2;template=results;type=batting', 1255)
# (u'GJ Rennie', {'year 1999': '72', 'year 1998': '82', 'year 1997': '244', 'year 1996': '6', 'year 2003': '50', 'year 2000': '10', 'year 2001': '153'})
# (u'M Mbangwa', 'http://stats.espncricinfo.com/ci/engine/player/55584.html?class=2;template=results;type=batting', 1256)
# (u'M Mbangwa', {'year 1999': '0', 'year 1998': '13', 'year 1997': '0', 'year 1996': '11', 'year 2002': '1', 'year 2000': '9'})
# (u'EZ Matambanadzo', 'http://stats.espncricinfo.com/ci/engine/player/55582.html?class=2;template=results;type=batting', 1257)
# (u'EZ Matambanadzo', {'year 1997': '6', 'year 1996': '2'})
# (u'DP Viljoen', 'http://stats.espncricinfo.com/ci/engine/player/55825.html?class=2;template=results;type=batting', 1258)
# (u'DP Viljoen', {'year 2000': '202', 'year 1997': '64', 'year 2001': '157', 'year 1999': '28', 'year 1998': '61'})
# (u'AG Huckle', 'http://stats.espncricinfo.com/ci/engine/player/55502.html?class=2;template=results;type=batting', 1259)
# (u'AG Huckle', {'year 1997': '1', 'year 1999': '0', 'year 1998': '8'})
# (u'MW Goodwin', 'http://stats.espncricinfo.com/ci/engine/player/55456.html?class=2;template=results;type=batting', 1260)
# (u'MW Goodwin', {'year 2000': '496', 'year 1999': '600', 'year 1998': '722'})
# (u'TN Madondo', 'http://stats.espncricinfo.com/ci/engine/player/55571.html?class=2;template=results;type=batting', 1261)
# (u'TN Madondo', {'year 2000': '103', 'year 2001': '37', 'year 1999': '41', 'year 1998': '10'})
# (u'ML Nkala', 'http://stats.espncricinfo.com/ci/engine/player/55663.html?class=2;template=results;type=batting', 1262)
# (u'ML Nkala', {'year 1998': '0', 'year 2002': '9', 'year 2000': '79', 'year 2001': '69', 'year 2006': '36', 'year 2004': '123', 'year 2005': '8'})
# (u'NC Johnson', 'http://stats.espncricinfo.com/ci/engine/player/55528.html?class=2;template=results;type=batting', 1263)
# (u'NC Johnson', {'year 2000': '589', 'year 1999': '739', 'year 1998': '351'})
# (u'AM Blignaut', 'http://stats.espncricinfo.com/ci/engine/player/55259.html?class=2;template=results;type=batting', 1264)
# (u'AM Blignaut', {'year 1999': '50', 'year 2010': '1', 'year 2002': '118', 'year 2003': '210', 'year 2000': '3', 'year 2001': '74', 'year 2004': '78', 'year 2005': '92'})
# (u'U Chatterjee', 'http://stats.espncricinfo.com/ci/engine/player/27603.html?class=2;template=results;type=batting', 1265)
# (u'U Chatterjee', {'year 1995': '6'})
# (u'R Dravid', 'http://stats.espncricinfo.com/ci/engine/player/28114.html?class=2;template=results;type=batting', 1266)
# (u'R Dravid', {'year 1999': '1761', 'year 1998': '283', 'year 1997': '951', 'year 1996': '475', 'year 2011': '124', 'year 2009': '180', 'year 2002': '913', 'year 2003': '623', 'year 2000': '980', 'year 2001': '740', 'year 2006': '919', 'year 2007': '823', 'year 2004': '1025', 'year 2005': '1092'})
# (u'V Rathour', 'http://stats.espncricinfo.com/ci/engine/player/33120.html?class=2;template=results;type=batting', 1267)
# (u'V Rathour', {'year 1997': '34', 'year 1996': '159'})
# (u'PL Mhambrey', 'http://stats.espncricinfo.com/ci/engine/player/30999.html?class=2;template=results;type=batting', 1268)
# (u'PL Mhambrey', {'year 1996': '7', 'year 1998': '0'})
# (u'SB Joshi', 'http://stats.espncricinfo.com/ci/engine/player/29725.html?class=2;template=results;type=batting', 1269)
# (u'SB Joshi', {'year 1999': '206', 'year 1998': '54', 'year 1997': '13', 'year 1996': '114', 'year 2000': '178', 'year 2001': '19'})
# (u'S Somasunder', 'http://stats.espncricinfo.com/ci/engine/player/34086.html?class=2;template=results;type=batting', 1270)
# (u'S Somasunder', {'year 1996': '16'})
# (u'P Dharmani', 'http://stats.espncricinfo.com/ci/engine/player/28067.html?class=2;template=results;type=batting', 1271)
# (u'P Dharmani', {'year 1996': '8'})
# (u'SS Karim', 'http://stats.espncricinfo.com/ci/engine/player/30042.html?class=2;template=results;type=batting', 1272)
# (u'SS Karim', {'year 2000': '49', 'year 1997': '287', 'year 1999': '18', 'year 1998': '8'})
# (u'D Ganesh', 'http://stats.espncricinfo.com/ci/engine/player/28774.html?class=2;template=results;type=batting', 1273)
# (u'D Ganesh', {'year 1997': '4'})
# (u'A Kuruvilla', 'http://stats.espncricinfo.com/ci/engine/player/30182.html?class=2;template=results;type=batting', 1274)
# (u'A Kuruvilla', {'year 1997': '26'})
# (u'RML Taylor', 'http://stats.espncricinfo.com/ci/engine/player/353431.html?class=2;template=results;type=batting', 1275)
# (u'RML Taylor', {'year 2013': '49', 'year 2015': '26', 'year 2014': '61', 'year 2016': '18'})
# (u'NM Carter', 'http://stats.espncricinfo.com/ci/engine/player/44493.html?class=2;template=results;type=batting', 1276)
# (u'NM Carter', {'year 2013': '0'})
# (u'FRJ Coleman', 'http://stats.espncricinfo.com/ci/engine/player/364329.html?class=2;template=results;type=batting', 1277)
# (u'FRJ Coleman', {'year 2013': '28', 'year 2015': '79', 'year 2014': '104'})
# (u'HJW Gardiner', 'http://stats.espncricinfo.com/ci/engine/player/638713.html?class=2;template=results;type=batting', 1278)
# (u'HJW Gardiner', {'year 2013': '25', 'year 2015': '125', 'year 2014': '112'})
# (u'MH Cross', 'http://stats.espncricinfo.com/ci/engine/player/417268.html?class=2;template=results;type=batting', 1279)
# (u'MH Cross', {'year 2019': '87', 'year 2018': '387', 'year 2015': '140', 'year 2014': '88', 'year 2017': '200', 'year 2016': '50'})
# (u'MA Leask', 'http://stats.espncricinfo.com/ci/engine/player/414966.html?class=2;template=results;type=batting', 1280)
# (u'MA Leask', {'year 2019': '8', 'year 2018': '134', 'year 2015': '60', 'year 2014': '119', 'year 2017': '97', 'year 2016': '25'})
# (u'DM Basden', 'http://stats.espncricinfo.com/ci/engine/player/278496.html?class=2;template=results;type=batting', 1281)
# (u'DM Basden', {'year 2007': '12'})
# (u'JJ Celestine', 'http://stats.espncricinfo.com/ci/engine/player/216811.html?class=2;template=results;type=batting', 1282)
# (u'JJ Celestine', {'year 2008': '22', 'year 2007': '38'})
# (u'J Edness', 'http://stats.espncricinfo.com/ci/engine/player/23759.html?class=2;template=results;type=batting', 1283)
# (u'J Edness', {'year 2008': '153', 'year 2007': '99'})
# (u'RJ Robinson', 'http://stats.espncricinfo.com/ci/engine/player/216996.html?class=2;template=results;type=batting', 1284)
# (u'RJ Robinson', {'year 2009': '10', 'year 2007': '17'})
# (u'CH Lonsdale', 'http://stats.espncricinfo.com/ci/engine/player/307528.html?class=2;template=results;type=batting', 1285)
# (u'CH Lonsdale', {'year 2007': '4'})
# (u'RJ Trott', 'http://stats.espncricinfo.com/ci/engine/player/267454.html?class=2;template=results;type=batting', 1286)
# (u'RJ Trott', {'year 2008': '73', 'year 2009': '10', 'year 2007': '47'})
# (u'KC Hodsoll', 'http://stats.espncricinfo.com/ci/engine/player/307235.html?class=2;template=results;type=batting', 1287)
# (u'KC Hodsoll', {'year 2008': '0', 'year 2007': '2'})
# (u'OO Bascome', 'http://stats.espncricinfo.com/ci/engine/player/279531.html?class=2;template=results;type=batting', 1288)
# (u'OO Bascome', {'year 2008': '65'})
# (u'CR Foggo', 'http://stats.espncricinfo.com/ci/engine/player/23700.html?class=2;template=results;type=batting', 1289)
# (u'CR Foggo', {'year 2008': '106'})
# (u'TE Tucker', 'http://stats.espncricinfo.com/ci/engine/player/307237.html?class=2;template=results;type=batting', 1290)
# (u'TE Tucker', {'year 2008': '0', 'year 2009': '0'})
# (u'DAW Hollis', 'http://stats.espncricinfo.com/ci/engine/player/307234.html?class=2;template=results;type=batting', 1291)
# (u'DAW Hollis', {'year 2008': '15'})
# (u'Abdul Razzaq', 'http://stats.espncricinfo.com/ci/engine/player/39836.html?class=2;template=results;type=batting', 1292)
# (u'Abdul Razzaq', {'year 1999': '367', 'year 1998': '93', 'year 1997': '8', 'year 1996': '0', 'year 2011': '159', 'year 2009': '125', 'year 2010': '331', 'year 2002': '675', 'year 2003': '600', 'year 2000': '661', 'year 2001': '384', 'year 2006': '455', 'year 2007': '62', 'year 2004': '640', 'year 2005': '520'})
# (u'Azam Khan', 'http://stats.espncricinfo.com/ci/engine/player/39020.html?class=2;template=results;type=batting', 1293)
# (u'Azam Khan', {'year 1996': '113', 'year 1998': '3'})
# (u'Zahoor Elahi', 'http://stats.espncricinfo.com/ci/engine/player/43701.html?class=2;template=results;type=batting', 1294)
# (u'Zahoor Elahi', {'year 1997': '82', 'year 1996': '215'})
# (u'Mohammad Wasim', 'http://stats.espncricinfo.com/ci/engine/player/41297.html?class=2;template=results;type=batting', 1295)
# (u'Mohammad Wasim', {'year 2000': '44', 'year 1997': '296', 'year 1996': '89', 'year 1998': '114'})
# (u'Mohammad Zahid', 'http://stats.espncricinfo.com/ci/engine/player/41299.html?class=2;template=results;type=batting', 1296)
# (u'Mohammad Zahid', {'year 2002': '0', 'year 1997': '1', 'year 1996': '0', 'year 1998': '14'})
# (u'Mujahid Jamshed', 'http://stats.espncricinfo.com/ci/engine/player/41310.html?class=2;template=results;type=batting', 1297)
# (u'Mujahid Jamshed', {'year 1997': '27'})
# (u'Ijaz Ahmed jnr', 'http://stats.espncricinfo.com/ci/engine/player/40553.html?class=2;template=results;type=batting', 1298)
# (u'Ijaz Ahmed jnr', {'year 1997': '3'})
# (u'Mohammad Hussain', 'http://stats.espncricinfo.com/ci/engine/player/41285.html?class=2;template=results;type=batting', 1299)
# (u'Mohammad Hussain', {'year 1997': '51', 'year 1998': '103'})
# (u'Akhtar Sarfraz', 'http://stats.espncricinfo.com/ci/engine/player/38986.html?class=2;template=results;type=batting', 1300)
# (u'Akhtar Sarfraz', {'year 1997': '52', 'year 1998': '14'})
# (u'Manzoor Akhtar', 'http://stats.espncricinfo.com/ci/engine/player/41264.html?class=2;template=results;type=batting', 1301)
# (u'Manzoor Akhtar', {'year 1997': '49', 'year 1998': '48'})
# (u'DL Maddy', 'http://stats.espncricinfo.com/ci/engine/player/16876.html?class=2;template=results;type=batting', 1302)
# (u'DL Maddy', {'year 2000': '112', 'year 1998': '1'})
# (u'ID Austin', 'http://stats.espncricinfo.com/ci/engine/player/8590.html?class=2;template=results;type=batting', 1303)
# (u'ID Austin', {'year 1999': '5', 'year 1998': '29'})
# (u'MW Alleyne', 'http://stats.espncricinfo.com/ci/engine/player/8520.html?class=2;template=results;type=batting', 1304)
# (u'MW Alleyne', {'year 2000': '75', 'year 1999': '76'})
# (u'VJ Wells', 'http://stats.espncricinfo.com/ci/engine/player/22365.html?class=2;template=results;type=batting', 1305)
# (u'VJ Wells', {'year 1999': '141'})
# (u'A Flintoff', 'http://stats.espncricinfo.com/ci/engine/player/12856.html?class=2;template=results;type=batting', 1306)
# (u'A Flintoff', {'year 1999': '100', 'year 2008': '301', 'year 2009': '3', 'year 2002': '397', 'year 2003': '631', 'year 2000': '206', 'year 2001': '144', 'year 2006': '102', 'year 2007': '387', 'year 2004': '633', 'year 2005': '490'})
# (u'CMW Read', 'http://stats.espncricinfo.com/ci/engine/player/19346.html?class=2;template=results;type=batting', 1307)
# (u'CMW Read', {'year 2003': '84', 'year 2000': '70', 'year 2006': '61', 'year 2004': '85'})
# (u'VS Solanki', 'http://stats.espncricinfo.com/ci/engine/player/20286.html?class=2;template=results;type=batting', 1308)
# (u'VS Solanki', {'year 2003': '277', 'year 2000': '96', 'year 2006': '83', 'year 2004': '349', 'year 2005': '292'})
# (u'GP Swann', 'http://stats.espncricinfo.com/ci/engine/player/20431.html?class=2;template=results;type=batting', 1309)
# (u'GP Swann', {'year 2013': '32', 'year 2008': '63', 'year 2009': '81', 'year 2011': '160', 'year 2010': '68', 'year 2000': '0', 'year 2012': '13', 'year 2007': '83'})
# (u'ME Trescothick', 'http://stats.espncricinfo.com/ci/engine/player/21585.html?class=2;template=results;type=batting', 1310)
# (u'ME Trescothick', {'year 2002': '950', 'year 2003': '867', 'year 2000': '441', 'year 2001': '442', 'year 2006': '412', 'year 2004': '670', 'year 2005': '553'})
# (u'PJ Franks', 'http://stats.espncricinfo.com/ci/engine/player/12906.html?class=2;template=results;type=batting', 1311)
# (u'PJ Franks', {'year 2000': '4'})
# (u'Fahad Alhashmi', 'http://stats.espncricinfo.com/ci/engine/player/220521.html?class=2;template=results;type=batting', 1312)
# (u'Fahad Alhashmi', {'year 2008': '0', 'year 2015': '0', 'year 2014': '0'})
# (u'Saqib Ali', 'http://stats.espncricinfo.com/ci/engine/player/42746.html?class=2;template=results;type=batting', 1313)
# (u'Saqib Ali', {'year 2008': '29', 'year 2014': '55'})
# (u'V Shetty', 'http://stats.espncricinfo.com/ci/engine/player/342182.html?class=2;template=results;type=batting', 1314)
# (u'V Shetty', {'year 2008': '7', 'year 2014': '9'})
# (u'EHSN Silva', 'http://stats.espncricinfo.com/ci/engine/player/50460.html?class=2;template=results;type=batting', 1315)
# (u'EHSN Silva', {'year 2008': '7'})
# (u'Zahid Shah', 'http://stats.espncricinfo.com/ci/engine/player/43735.html?class=2;template=results;type=batting', 1316)
# (u'Zahid Shah', {'year 2008': '11'})
# (u'Alawi Shukri', 'http://stats.espncricinfo.com/ci/engine/player/332921.html?class=2;template=results;type=batting', 1317)
# (u'Alawi Shukri', {'year 2008': '1'})
# (u'Aman Ali', 'http://stats.espncricinfo.com/ci/engine/player/319613.html?class=2;template=results;type=batting', 1318)
# (u'Aman Ali', {'year 2008': '0'})
# (u'GS Trimble', 'http://stats.espncricinfo.com/ci/engine/player/7970.html?class=2;template=results;type=batting', 1319)
# (u'GS Trimble', {'year 1986': '4'})
# (u'TJ Zoehrer', 'http://stats.espncricinfo.com/ci/engine/player/8468.html?class=2;template=results;type=batting', 1320)
# (u'TJ Zoehrer', {'year 1986': '17', 'year 1987': '104', 'year 1994': '9'})
# (u'GC Dyer', 'http://stats.espncricinfo.com/ci/engine/player/4996.html?class=2;template=results;type=batting', 1321)
# (u'GC Dyer', {'year 1986': '51', 'year 1987': '50', 'year 1988': '73'})
# (u'GA Bishop', 'http://stats.espncricinfo.com/ci/engine/player/4151.html?class=2;template=results;type=batting', 1322)
# (u'GA Bishop', {'year 1987': '13'})
# (u'PL Taylor', 'http://stats.espncricinfo.com/ci/engine/player/7926.html?class=2;template=results;type=batting', 1323)
# (u'PL Taylor', {'year 1988': '91', 'year 1989': '87', 'year 1987': '43', 'year 1991': '16', 'year 1990': '142', 'year 1992': '58'})
# (u'MRJ Veletta', 'http://stats.espncricinfo.com/ci/engine/player/8105.html?class=2;template=results;type=batting', 1324)
# (u'MRJ Veletta', {'year 1987': '141', 'year 1988': '326', 'year 1989': '17'})
# (u'TM Moody', 'http://stats.espncricinfo.com/ci/engine/player/6628.html?class=2;template=results;type=batting', 1325)
# (u'TM Moody', {'year 1999': '198', 'year 1998': '247', 'year 1989': '52', 'year 1987': '10', 'year 1997': '4', 'year 1996': '11', 'year 1991': '66', 'year 1990': '219', 'year 1992': '404'})
# (u'TBA May', 'http://stats.espncricinfo.com/ci/engine/player/6534.html?class=2;template=results;type=batting', 1326)
# (u'TBA May', {'year 1988': '0', 'year 1989': '2', 'year 1995': '3', 'year 1987': '16', 'year 1993': '4', 'year 1992': '0', 'year 1994': '14'})
# (u'AK Zesers', 'http://stats.espncricinfo.com/ci/engine/player/8466.html?class=2;template=results;type=batting', 1327)
# (u'AK Zesers', {'year 1987': '10'})
# (u'AIC Dodemaide', 'http://stats.espncricinfo.com/ci/engine/player/4964.html?class=2;template=results;type=batting', 1328)

# %%
with open("../../../finalresfile.json", "w") as write_file:
    json.dump(final_res, write_file)

# %%
final_res

# %%
content/finalresfile.json
